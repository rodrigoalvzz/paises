# %%
import requests
import pandas as pd
import time

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

# %%
def get_country_data():
    url = "https://restcountries.com/v2/all"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for any errors

        data = response.json()  # Parse the response as JSON
        return data
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return None

# Example usage
country_data = get_country_data()

if country_data:
    # Process and display the country data
    for country in country_data:
        print("Country:", country["name"])
        if "capital" in country:
            print("Capital:", country["capital"])
        else:
            print("Capital: Not available")
        print("Population:", country["population"])
        print("Region:", country["region"])
        print("------------")
else:
    print("Failed to retrieve country data.")
# Out:
# Country: Afghanistan
# Capital: Kabul
# Population: 40218234
# Region: Asia
# ------------
# Country: Åland Islands
# Capital: Mariehamn
# Population: 28875
# Region: Europe
# ------------
# Country: Albania
# Capital: Tirana
# Population: 2837743
# Region: Europe
# ------------
# Country: Algeria
# Capital: Algiers
# Population: 44700000
# Region: Africa
# ------------
# Country: American Samoa
# Capital: Pago Pago
# Population: 55197
# Region: Oceania
# ------------
# Country: Andorra
# Capital: Andorra la Vella
# Population: 77265
# Region: Europe
# ------------
# Country: Angola
# Capital: Luanda
# Population: 32866268
# Region: Africa
# ------------
# Country: Anguilla
# Capital: The Valley
# Population: 13452
# Region: Americas
# ------------
# Country: Antarctica
# Capital: Not available
# Population: 1000
# Region: Polar
# ------------
# Country: Antigua and Barbuda
# Capital: Saint John's
# Population: 97928
# Region: Americas
# ------------
# Country: Argentina
# ...

# %%
# Expresando los datos en forma de tabla
country_data = get_country_data()

if country_data:
    # Prepare the table data
    table_data = []
    for country in country_data:
        table_row = [
            country.get("name", ""),
            country.get("capital", "Not available"),
            country.get("population", ""),
            country.get("region", "")
        ]
        table_data.append(table_row)

    # Display the table
    headers = ["Country", "Capital", "Population", "Region"]
    print(tabulate(table_data, headers=headers, tablefmt="grid"))
else:
    print("Failed to retrieve country data.")
# Out:
# +------------------------------------------------------+---------------------------+--------------+-----------------+
# | Country                                              | Capital                   |   Population | Region          |
# +======================================================+===========================+==============+=================+
# | Afghanistan                                          | Kabul                     |     40218234 | Asia            |
# +------------------------------------------------------+---------------------------+--------------+-----------------+
# | Åland Islands                                        | Mariehamn                 |        28875 | Europe          |
# +------------------------------------------------------+---------------------------+--------------+-----------------+
# | Albania                                              | Tirana                    |      2837743 | Europe          |
# ...

# %%
pip install sqlalchemy-redshift
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install redshift_connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sqlalchemy-redshift 0.8.14 requires SQLAlchemy<2.0.0,>=0.9.2, but you have sqlalchemy 2.0.19 which is incompatible.
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.32
#     Uninstalling SQLAlchemy-1.4.32:
#       Successfully uninstalled SQLAlchemy-1.4.32
# ...

# %%
import sqlalchemy as sa
from sqlalchemy.engine.url import URL
from sqlalchemy.orm import Session
# %reload_ext sql
# %config SqlMagic.displaylimit = 25

# %%
connect_to_db = URL.create(
drivername='redshift+redshift_connector',     host='data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com',     
port=5439,  
database='data-engineer-database',  
username='rodrigoleonelalvarez_coderhouse',  
password='qrdWA2847A'  
)
# %sql $connect_to_db
# %sql select current_user, version();
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\pkg_resources\__init__.py", line 3024, in _dep_map
#     return self.__dep_map
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\pkg_resources\__init__.py", line 2821, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\pkg_resources\__init__.py", line 3015, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\pkg_resources\__init__.py", line 2821, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# %sql select * from part limit 5
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\Windows 10\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
